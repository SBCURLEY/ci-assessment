# %% [markdown]
# <h1 align="center">Higher Diploma in Science in Computing (Data Analytics)</h1>
# <h1 align="center">Computer Infrastructure - Task 8</h1>

# %% [markdown]
# # Table of Contents
# ***
# 1. Description
# 2. Explore the Tasks
#     -   Task 1: Create Directory Structure
#     -   Task 2: Timestamps
#     -   Task 3: Formatting Timestamps
#     -   Task 4: Create Timestamped Files
#     -   Task 5: Download Today's Weather Data
#     -   Task 6: Timestamp the Data
#     -   Task 7: Write the Script
#     -   Task 9: Pandas
#
# 3. References

# %% [markdown]
# # 1. Description
# ***
# The following notebook will outline all of the weekly tasks 1-7 for the Computer Infrastructure Module.

# %% [markdown]
# # 2. Explore the Tasks
# ***

# %% [markdown]
# ## Task 1: Create Directory Structure
# Using the command line, I created a directory named `data` at the root of my repository with two subdirectories using `mkdir -p data\weather` and a second command `mkdir -p data\timestamps`. The main directory `data`and the two sub directories `timestamps` and `weather` are created.
#
# ### Command Line
# ```bash
# $ mkdir -p data\weather
#
# $ mkdir -p data\timestamps
# ````
# ### Output
#
# ![alt text](./images/task_01.png)
#
# ![image.png](attachment:image.png)
#
#
# ### References
# - Linus Today: Linux mkdir Command Explained for Beginners (with examples) - https://www.linuxtoday.com/news/linux-mkdir-command-explained-for-beginners-with-examples/
# - Linux die.net: mkdir(2) - Linux man page  https://linux.die.net/man/2/mkdir
# - Stack Overflow: Uploading a empty folder to github [duplicate] - https://stackoverflow.com/questions/8281322/uploading-a-empty-folder-to-github

# %% [markdown]
# ## Task 2: Timestamps
# I navigated to the data/timestamps directory. I used the date command to output the current date and time using the below function, I was able to output the current date & time to a new folder called `“now.txt”`. I ran the program ten times appending the output to the file named `“now.txt”`. I ensured the correct operator was being used. (>> append as opposed to > override). I checked the contents of `“now.txt”` using `cat` and `more`. The `cat` command outputs a file without a pause. So the entire contents of the file are output to the terminal and the terminal scrolls to the end of the file. With the `more` command, the output stops at the end of the terminal screen allowing you to scroll down using the space key (to scroll a page) or the enter key (scroll line by line) on your keyboard. As I generated the code 10 times, each datetime was updated 10 times to `“now.txt”`.
#
# ### Command Line
# ```bash
# date +"%Y%m%d_%H%M%S" >> now.txt
#
# cat now.txt
#
# more now.txt
# ````
#
# ### Output
# ![alt text](./images/task_02.png)
#
# ### References
# - Stack Overflow: How to append output to the end of a text file - https://stackoverflow.com/questions/6207573/how-to-append-output-to-the-end-of-a-text-file
# - Linus for Devices: How to append text to the end of a file in Linux - https://www.linuxfordevices.com/tutorials/linux/append-text-to-the-end-of-a-file-in-linux
# - Linus for Devices: The cat and more commands in Linux - https://www.linuxfordevices.com/tutorials/linux/cat-more-command-in-linux

# %% [markdown]
# ## Task 3: Formatting Timestamps
# I ran the date command again, but this time I formated the output using YYYYmmdd_HHMMSS. I referred to the date man page for more formatting options. I appended the formatted output to a file named `formatted.txt`.
#
# ### Command Line
# ```bash
# date +"%Y%m%d_%H%M%S" >> formatted.txt
# ````
#
# ### Output
# ![image.png](attachment:image.png)
#
#
# ## References
# - Linusize: Grep Command in Linux - https://linuxize.com/post/how-to-use-grep-command-to-search-files-in-linux/
# - Cyberciti: How To Format Date For Display or Use In a Shell Script - https://www.cyberciti.biz/faq/linux-unix-formatting-dates-for-display/
# - Squash: Formatting and Displaying Dates with Bash Scripts in Linux - https://www.squash.io/formatting-and-displaying-dates-with-bash-scripts-in-linux/

# %% [markdown]
# ## Task 4: Create Timestamped Files
# I used the `touch` command to create an empty file with a name in the YYYYmmdd_HHMMSS.txt format. I achieved this by embedding my date command in backticks ` into the touch command.
#
# ### Command Line
# ```bash
# touch `date +"%Y%m%d_%H%M%S.txt"`
# ````
#
# ### Output
#
# ![image.png](attachment:image.png)
#
# ### References
# - Turling.com: Using the Linux Free Command With Examples      https://www.turing.com/kb/how-to-use-the-linux-free-command
# - Stack Overflow: How to create a file with todays date in the filename  https://stackoverflow.com/questions/48270960/how-to-create-a-file-with-todays-date-in-the-filename
# - Make Tech easier: How to Use Touch Command in Linux    https://www.maketecheasier.com/use-touch-command-in-linux/

# %% [markdown]
# ## Task 5: Download Today's Weather Data
# In the data/weather directory, I downloaded the latest weather data for the Athenry weather station from Met Eireann using `wget`. I used the -O <filename> option to save the file as `weather.json`. The data can be found at this URL:
#
# https://prodapi.metweb.ie/observations/athenry/today.
#
#
# ### Command Line
# ```bash
# $ wget -O weather.json https://prodapi.metweb.ie/observations/athenry/today
# ````
#
# ### Output
#
# ![image.png](attachment:image.png)
#
#
# ### References
# - Linus Config :Download file from URL on Linux using command line https://linuxconfig.org/download-file-from-url-on-linux-using-command-line
# - How to Geek: How to Use wget, the Ultimate Command Line Downloading Tool  https://www.howtogeek.com/281663/how-to-use-wget-the-ultimate-command-line-downloading-tool/

# %% [markdown]
# ## Task 6: Timestamp the Data
# I modified the command from Task 5 to save the downloaded file with a timestamped name in the format YYYYmmdd_HHMMSS.json. This creates a new file with the date and time as a timestamp. It can be run multiple times. I have used `wget` and `curl` for this task. The command `curl --verbose -o` gives us alot of additional information on the url.
#
#
# ### Command Line
# ```bash
# wget -O `date +"%Y%m%d_%H%M%S.json"` https://prodapi.metweb.ie/observations/athenry/today
#
# curl -o `date +"%Y%m%d_%H%M%S.json"` https://prodapi.metweb.ie/observations/athenry/today
#
# curl --verbose -o
# ````
#
# ### Output
#
# ![alt text](./images/task_06_wget.png)
#
#
# ![alt text](./images/task_06_curl.png)
#
#
# ### References
# - Linus Handbook: What's the Difference Between curl and Wget? https://linuxhandbook.com/curl-wget-difference/
# - The Linux Code: Demystifying the curl vs wget Debate for Linux Users - History - https://thelinuxcode.com/what-is-the-difference-between-wget-vs-curl/
# - Everything Curl - Command line options  https://everything.curl.dev/cmdline/options/index.html

# %% [markdown]
# ## Task 7: Write the Script
# I wrote a bash script called `weather.sh` in the root of my repository. This script automates the process from Task 6, saving the weather data to the data/weather directory. I made the script executable by changing the mode of the file to execute using `chmod u+x ./weather.sh`. I tested it by running it. I needed to use the ./executable file on Linux to run the executable script. I can now run the command multiple times using `weather.sh`
#
# ### Command Line
# ```bash
# ll  on root
#
# chmod u+x ./weather.sh
#
# ./weather.sh
# ````
#
#
# ### Output
#
# weather.sh not executable  rw-rw-rw
#
# ![alt text](./images/task_07_rw.png)
#
# Following the chmod u+x ./weather.sh   rwxrw-rw
#
# ![alt text](./images/task_07_rwx.png)
#
#
# ![alt text](./images/task_07_script.png)
#
#
# ### References
# - Askubuntu: How to make a file (e.g. a .sh script) executable, so it can be run from a terminal https://askubuntu.com/questions/229589/how-to-make-a-file-e-g-a-sh-script-executable-so-it-can-be-run-from-a-termi
# - Runcloud:Mastering the Echo Command in Linux (with Practical Examples)  https://runcloud.io/blog/echo-command-in-linux
# - Digital Ocean: How To View and Update the Linux PATH Environment Variable  https://www.digitalocean.com/community/tutorials/how-to-view-and-update-the-linux-path-environment-variable

# %% [markdown]
# ## Task 9: Pandas
# ### 9.1. Description
# I used the pandas function read_json() to load in the weather data file `20241113_175630.json`. I will explore and summarise the data. This file contains a list of of observations for every hour of the current day for the weather station in Athenry, Co Galway. The file is updated hourly. Time values are Local times.
# Values for each hour include:
# - Name
# - Dry bulb temperature in whole degrees
# - Weather description
# - Windspeed (kt)
# - Cardinal Wind Direction
# - Relative Humidity (%)
# - Rainfall (mm); msl
# - Pressure (mbar)
# - Day of the week
# - Date
# - Time of observation

# %% [markdown]
# ### 9.2. Import the Libraries
#
# I imported the following libraries to plot the dataset.
#
# - `matplotlib.pyplot`: Essential for creating static, animated, and interactive visualizations in Python. It is closely integrated with NumPy and provides a MATLAB-like interface for creating plots and visualizations.
# - `numpy`: It contains functionality for multidimensional arrays, high-level mathematical functions such as linear algebra operations.
# - `pandas`: Fundamental data analysis and manipulation library built on top of the Python programming language. It offers data structures and operations for manipulating numerical tables and time series.
# - `seaborn`: Seaborn is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics.
# - `datetime`: The datetime is a built-in module that provides classes for manipulating dates and times

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import datetime

# %% [markdown]
# ### 9.2. Load the Data
#
# Load the data from `.data/weather/20241111_063407.json`

# %%
df=pd.read_json("data/weather/20241111_063407.json")

# %% [markdown]
# ### 9.3 Data Exploration

# %% [markdown]
# #### 9.3.1 Check the dataframe

# %%
df.head(5)
# Out:
#       name  temperature symbol weatherDescription              text  \
# 0  Athenry            3    15n         Fog / Mist             "Fog"
# 1  Athenry            3    15n         Fog / Mist    "Fog thinning"
# 2  Athenry            2    15n         Fog / Mist  "Fog thickening"
# 3  Athenry            2    15n         Fog / Mist      "Recent Fog"
# 4  Athenry            2    15n         Fog / Mist  "Fog thickening"
#
#    windSpeed windGust cardinalWindDirection  windDirection  humidity  \
# 0          2        -                    NE             45        98
# 1          2        -                    NE             45        99
# 2          4        -                    NE             45        98
# 3          2        -                    NE             45        98
# 4          4        -                     E             90        98
#
#    rainfall  pressure dayName       date reportTime
# 0       0.0      1035  Monday 2024-11-11      00:00
# 1       0.0      1035  Monday 2024-11-11      01:00
# 2       0.1      1035  Monday 2024-11-11      02:00
# 3       0.0      1036  Monday 2024-11-11      03:00
# 4       0.0      1036  Monday 2024-11-11      04:00

# %% [markdown]
# #### 9.3.2  Check for the DataFrame dimensionality with pandas .info() method

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   name                   7 non-null      object
#  1   temperature            7 non-null      int64
#  2   symbol                 7 non-null      object
#  3   weatherDescription     7 non-null      object
#  4   text                   7 non-null      object
#  5   windSpeed              7 non-null      int64
#  6   windGust               7 non-null      object
#  7   cardinalWindDirection  7 non-null      object
#  8   windDirection          7 non-null      int64
#  9   humidity               7 non-null      int64
#  10  rainfall               7 non-null      float64
#  11  pressure               7 non-null      int64
#  12  dayName                7 non-null      object
#  13  date                   7 non-null      datetime64[ns]
#  14  reportTime             7 non-null      object
# dtypes: datetime64[ns](1), float64(1), int64(5), object(8)
# memory usage: 972.0+ bytes

# %% [markdown]
# #### 9.3.2  Generate descriptive statistics with pandas .describe method

# %%
df.describe(include="all")
# Out:
#            name  temperature symbol weatherDescription              text  \
# count         7     7.000000      7                  7                 7
# unique        1          NaN      1                  1                 5
# top     Athenry          NaN    15n         Fog / Mist  "Fog thickening"
# freq          7          NaN      7                  7                 2
# mean        NaN     2.285714    NaN                NaN               NaN
# min         NaN     2.000000    NaN                NaN               NaN
# 25%         NaN     2.000000    NaN                NaN               NaN
# 50%         NaN     2.000000    NaN                NaN               NaN
# 75%         NaN     2.500000    NaN                NaN               NaN
# max         NaN     3.000000    NaN                NaN               NaN
# std         NaN     0.487950    NaN                NaN               NaN
#
#         windSpeed windGust cardinalWindDirection  windDirection   humidity  \
# count    7.000000        7                     7       7.000000   7.000000
# unique        NaN        1                     3            NaN        NaN
# top           NaN        -                    NE            NaN        NaN
# freq          NaN        7                     5            NaN        NaN
# mean     2.857143      NaN                   NaN      45.000000  98.285714
# min      2.000000      NaN                   NaN       0.000000  98.000000
# 25%      2.000000      NaN                   NaN      45.000000  98.000000
# 50%      2.000000      NaN                   NaN      45.000000  98.000000
# 75%      4.000000      NaN                   NaN      45.000000  98.500000
# max      4.000000      NaN                   NaN      90.000000  99.000000
# std      1.069045      NaN                   NaN      25.980762   0.487950
#
#         rainfall     pressure dayName                 date reportTime
# count   7.000000     7.000000       7                    7          7
# unique       NaN          NaN       1                  NaN          7
# top          NaN          NaN  Monday                  NaN      00:00
# freq         NaN          NaN       7                  NaN          1
# mean    0.014286  1035.857143     NaN  2024-11-11 00:00:00        NaN
# min     0.000000  1035.000000     NaN  2024-11-11 00:00:00        NaN
# 25%     0.000000  1035.000000     NaN  2024-11-11 00:00:00        NaN
# 50%     0.000000  1036.000000     NaN  2024-11-11 00:00:00        NaN
# 75%     0.000000  1036.500000     NaN  2024-11-11 00:00:00        NaN
# max     0.100000  1037.000000     NaN  2024-11-11 00:00:00        NaN
# std     0.037796     0.899735     NaN                  NaN        NaN

# %% [markdown]
# ### 9.3 Data Analysis

# %%
print(df.isna().sum())              # check for  missing data
# Out:
# name                     0
# temperature              0
# symbol                   0
# weatherDescription       0
# text                     0
# windSpeed                0
# windGust                 0
# cardinalWindDirection    0
# windDirection            0
# humidity                 0
# rainfall                 0
# pressure                 0
# dayName                  0
# date                     0
# reportTime               0
# dtype: int64

# %%
df['reportTime']                        # checking the dtype of the time stamp
# Out:
# 0    00:00
# 1    01:00
# 2    02:00
# 3    03:00
# 4    04:00
# 5    05:00
# 6    06:00
# Name: reportTime, dtype: object

# %%
pd.to_datetime(df['reportTime'])            # change the dtype from object to datetime
# Out:
# /tmp/ipykernel_37309/2869371080.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(df['reportTime'])            # change the dtype from object to datetime
# 0   2024-11-13 00:00:00
# 1   2024-11-13 01:00:00
# 2   2024-11-13 02:00:00
# 3   2024-11-13 03:00:00
# 4   2024-11-13 04:00:00
# 5   2024-11-13 05:00:00
# 6   2024-11-13 06:00:00
# Name: reportTime, dtype: datetime64[ns]

# %%
df.set_index('reportTime', inplace=True)      # set index to time so I can plot against it
df.head(10)
# Out:
#                name  temperature symbol weatherDescription              text  \
# reportTime
# 00:00       Athenry            3    15n         Fog / Mist             "Fog"
# 01:00       Athenry            3    15n         Fog / Mist    "Fog thinning"
# 02:00       Athenry            2    15n         Fog / Mist  "Fog thickening"
# 03:00       Athenry            2    15n         Fog / Mist      "Recent Fog"
# 04:00       Athenry            2    15n         Fog / Mist  "Fog thickening"
# 05:00       Athenry            2    15n         Fog / Mist      "Recent Fog"
# 06:00       Athenry            2    15n         Fog / Mist            "Mist"
#
#             windSpeed windGust cardinalWindDirection  windDirection  humidity  \
# reportTime
# 00:00               2        -                    NE             45        98
# 01:00               2        -                    NE             45        99
# 02:00               4        -                    NE             45        98
# 03:00               2        -                    NE             45        98
# 04:00               4        -                     E             90        98
# 05:00               4        -                    NE             45        99
# 06:00               2        -                     N              0        98
#
#             rainfall  pressure dayName       date
# reportTime
# 00:00            0.0      1035  Monday 2024-11-11
# 01:00            0.0      1035  Monday 2024-11-11
# 02:00            0.1      1035  Monday 2024-11-11
# 03:00            0.0      1036  Monday 2024-11-11
# 04:00            0.0      1036  Monday 2024-11-11
# 05:00            0.0      1037  Monday 2024-11-11
# 06:00            0.0      1037  Monday 2024-11-11

# %%
plt.figure(figsize=(6, 4))
sns.set_style('darkgrid')
sns.set_palette("BrBG_r")
sns.lineplot(data=df, x="reportTime", y="temperature").set(title="Athenry Hourly Temperature",xlabel="Time",ylabel="Temperature (Celsius)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.set_style('darkgrid')
sns.set_palette("BrBG_r")
sns.lineplot(data=df, x="reportTime", y="windSpeed").set(title="Athenry Hourly Windspeed",xlabel="Time",ylabel="Windspeed")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.set_style('darkgrid')
sns.set_palette("BrBG_r")
sns.lineplot(data=df, x="reportTime", y="rainfall").set(title="Athenry Hourly Rainfall",xlabel="Time",ylabel="Rainfall")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
mean_temp = df['temperature'].mean()
print(f"Mean Temperature: {mean_temp}°C")
# Out:
# Mean Temperature: 2.2857142857142856°C

# %% [markdown]
# ### References
# - Pandas Pydata: pandas.read_json   https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_json.html

# %% [markdown]
# # 3. References Tasks 1-7
# ***
#
# - All lectures 1-7 -  Computer Infrastructure - Ian McLoughlin
# - Linus Today: Linux mkdir Command Explained for Beginners (with examples) - https://www.linuxtoday.com/news/linux-mkdir-command-explained-for-beginners-with-examples/
# - Linux die.net: mkdir(2) - Linux man page  https://linux.die.net/man/2/mkdir
# - Stack Overflow: Uploading a empty folder to github [duplicate] - https://stackoverflow.com/questions/8281322/uploading-a-empty-folder-to-github
# - Stack Overflow: How to append output to the end of a text file - https://stackoverflow.com/questions/6207573/how-to-append-output-to-the-end-of-a-text-file
# - Linus for Devices: How to append text to the end of a file in Linux - https://www.linuxfordevices.com/tutorials/linux/append-text-to-the-end-of-a-file-in-linux
# - Linus for Devices: The cat and more commands in Linux - https://www.linuxfordevices.com/tutorials/linux/cat-more-command-in-linux
# - Linusize: Grep Command in Linux - https://linuxize.com/post/how-to-use-grep-command-to-search-files-in-linux/
# - Cyberciti: How To Format Date For Display or Use In a Shell Script - https://www.cyberciti.biz/faq/linux-unix-formatting-dates-for-display/
# - Squash: Formatting and Displaying Dates with Bash Scripts in Linux - https://www.squash.io/formatting-and-displaying-dates-with-bash-scripts-in-linux/
# - Turling.com: Using the Linux Free Command With Examples      https://www.turing.com/kb/how-to-use-the-linux-free-command
# - Stack Overflow: How to create a file with todays date in the filename  https://stackoverflow.com/questions/48270960/how-to-create-a-file-with-todays-date-in-the-filename
# - Make Rech easier: How to Use Touch Command in Linux    https://www.maketecheasier.com/use-touch-command-in-linux/
# - Linus Config :Download file from URL on Linux using command line https://linuxconfig.org/download-file-from-url-on-linux-using-command-line
# - How to Geek: How to Use wget, the Ultimate Command Line Downloading Tool  https://www.howtogeek.com/281663/how-to-use-wget-the-ultimate-command-line-downloading-tool/
# - Linus Handbook: What's the Difference Between curl and Wget? https://linuxhandbook.com/curl-wget-difference/
# - The Linux Code: Demystifying the curl vs wget Debate for Linux Users - History - https://thelinuxcode.com/what-is-the-difference-between-wget-vs-curl/
# - Everything Curl - Command line options  https://everything.curl.dev/cmdline/options/index.html
# - Askubuntu: How to make a file (e.g. a .sh script) executable, so it can be run from a terminal https://askubuntu.com/questions/229589/how-to-make-a-file-e-g-a-sh-script-executable-so-it-can-be-run-from-a-termi
# - Runcloud: Mastering the Echo Command in Linux (with Practical Examples)  https://runcloud.io/blog/echo-command-in-linux
# - Digital Ocean: How To View and Update the Linux PATH Environment Variable  https://www.digitalocean.com/community/tutorials/how-to-view-and-update-the-linux-path-environment-variable

# %% [markdown]
# ### Task 9
# ***

# %%
# Read the data
# https://data.gov.ie/dataset/todays-weather-claremorris
df=pd.read_json("")

# %% [markdown]
# # End
#
# ***
